# %% [markdown]
# ## Load Data

# %%
import numpy as np
import pandas as pd
from random import sample
from libs.utils import *

# %%
path_to_data = "C:/Users/Admin/DA_Projects/online_retail.txt"
min_support = 0.05
min_confidence = 0.6
path_to_order = "C:/Users/Admin/DA_Projects/order.txt"

# %%
order = load_order(path_to_order)
transactions = load_transactions(path_to_data, order)
sampled_transactions = transactions[:int(len(transactions) * 0.01)] 
filtered_transactions = [t for t in sampled_transactions if len(t) < 10]
if len(filtered_transactions) > 50:
    filtered_transactions = sample(filtered_transactions, 50)
flattened_items = [item for sublist in filtered_transactions for item in sublist]
order = sorted(set(flattened_items))
print(order)
# Out:
# ['3 PIECE SPACEBOY COOKIE CUTTER SET', 'ALARM CLOCK BAKELIKE CHOCOLATE', 'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED', 'ANTIQUE GLASS DRESSING TABLE POT', 'ANTIQUE TALL SWIRLGLASS TRINKET POT', 'ASSORTED BOTTLE TOP  MAGNETS', 'ASSORTED COLOUR BIRD ORNAMENT', 'ASSORTED COLOUR MINI CASES', 'BAG 125g SWIRLY MARBLES', 'BAKING SET SPACEBOY DESIGN', 'BATH BUILDING BLOCK WORD', 'BLACK HEART CARD HOLDER', 'BLACK KITCHEN SCALES', 'BLACK RECORD COVER FRAME', 'BLUE BIRDHOUSE DECORATION', 'BLUE COAT RACK PARIS FASHION', 'BLUE DRAWER KNOB ACRYLIC EDWARDIAN', 'BREAD BIN DINER STYLE PINK', 'BREAD BIN DINER STYLE RED', 'CANDLEHOLDER PINK HANGING HEART', 'CERAMIC CAKE STAND + HANGING CAKES', 'CERAMIC HEART FAIRY CAKE MONEY BANK', 'CERAMIC STRAWBERRY CAKE MONEY BANK', 'CERAMIC STRAWBERRY DESIGN MUG', 'CHEST OF DRAWERS GINGHAM HEART', 'CHILDS BREAKFAST SET SPACEBOY', 'CHINESE DRAGON PAPER LANTERNS', 'CHOCOLATE HOT WATER BOTTLE', 'CHRISTMAS GINGHAM HEART', 'CHRISTMAS LIGHTS 10 REINDEER', 'CHRISTMAS MUSICAL ZINC HEART', 'CHRISTMAS MUSICAL ZINC STAR', 'CHRISTMAS TREE DECORATION WITH BELL', 'CHRISTMAS TREE STAR DECORATION', 'CINAMMON SET OF 9 T-LIGHTS', 'CIRCUS PARADE CHILDRENS EGG CUP', 'CLASSICAL ROSE SMALL VASE', 'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN', 'CREAM CUPID HEARTS COAT HANGER', 'CREAM HEART CARD HOLDER', 'CREAM SLICE FLANNEL CHOCOLATE SPOT', 'CREAM SLICE FLANNEL PINK SPOT', 'CREAM SWEETHEART EGG HOLDER', 'CUPCAKE LACE PAPER SET 6', 'DECORATIVE PLANT POT WITH FRIEZE', "DOCTOR'S BAG SOFT TOY", 'DOVE DECORATION PAINTED ZINC', 'ENAMEL WASH BOWL CREAM', 'FAMILY PHOTO FRAME CORNICE', 'FAUX FUR CHOCOLATE THROW', 'FLUTED ANTIQUE CANDLE HOLDER', 'FOLKART ZINC HEART CHRISTMAS DEC', 'FRENCH BLUE METAL DOOR SIGN 5', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'GLITTER CHRISTMAS HEART', 'GRAND CHOCOLATECANDLE', 'GREEN DRAWER KNOB ACRYLIC EDWARDIAN', 'GREEN REGENCY TEACUP AND SAUCER', 'GREY HEART HOT WATER BOTTLE', 'GROW YOUR OWN FLOWERS SET OF 3', 'HAND WARMER BABUSHKA DESIGN', 'HAND WARMER BIRD DESIGN', 'HAND WARMER OWL DESIGN', 'HAND WARMER RED POLKA DOT', 'HAND WARMER RED RETROSPOT', 'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER UNION JACK', 'HANGING HEART ZINC T-LIGHT HOLDER', 'HOMEMADE JAM SCENTED CANDLES', 'HOT WATER BOTTLE BABUSHKA', 'HOT WATER BOTTLE I AM SO POORLY', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'IVORY DINER WALL CLOCK', 'IVORY KITCHEN SCALES', 'JAM JAR WITH GREEN LID', 'JAM JAR WITH PINK LID', 'JAM MAKING SET PRINTED', 'JAM MAKING SET WITH JARS', 'JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'LANTERN CREAM GAZEBO', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BOX I LOVE LONDON', 'MA CAMPAGNE CUTLERY BOX', 'METAL 4 HOOK HANGER FRENCH CHATEAU', 'MULTI COLOUR SILVER T-LIGHT HOLDER', 'NAMASTE SWAGAT INCENSE', 'NATURAL SLATE HEART CHALKBOARD', 'ORGANISER WOOD ANTIQUE WHITE', 'PACK OF 12 COLOURED PENCILS', 'PACK OF 12 LONDON TISSUES', 'PACK OF 12 SKULL TISSUES', "PAPER CHAIN KIT 50'S CHRISTMAS", 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 'PINK DRAWER KNOB ACRYLIC EDWARDIAN', 'PLASTERS IN TIN STRONGMAN', 'POLKADOT PEN', 'PORCELAIN ROSE LARGE', 'PORCELAIN ROSE SMALL', 'POSTAGE', 'RED  HARMONICA IN BOX', 'RED COAT RACK PARIS FASHION', 'RED DRAWER KNOB ACRYLIC EDWARDIAN', 'RED HANGING HEART T-LIGHT HOLDER', 'RED HEART SHAPE LOVE BUCKET', 'RED KITCHEN SCALES', 'RED RETROSPOT CAKE STAND', 'RED RETROSPOT OVEN GLOVE', 'RED STRIPE CERAMIC DRAWER KNOB', 'RED WOOLLY HOTTIE WHITE HEART.', 'REGENCY CAKESTAND 3 TIER', 'RETROSPOT CHILDRENS APRON', 'RETROSPOT HEART HOT WATER BOTTLE', 'RETROSPOT LAMP', 'RETROSPOT RED WASHING UP GLOVES', 'ROSE COTTAGE KEEPSAKE BOX', 'ROTATING LEAVES T-LIGHT HOLDER', 'SCENTED CANDLE IN DIGITALIS TIN', 'SET 2 TEA TOWELS I LOVE LONDON', 'SET 7 BABUSHKA NESTING BOXES', 'SET OF 2 CHRISTMAS DECOUPAGE CANDLE', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 'SET OF 3 NOTEBOOK ...

# %%
sum = 0
for sublist in filtered_transactions:
    sum += len(sublist)
print(sum)
# Out:
# 179

# %%
len(filtered_transactions)
# Out:
# 50

# %%
len(order)
# Out:
# 142

# %% [markdown]
# ## Initialization

# %%
C = {}
L = {}
itemset_size = 1
discarded = {itemset_size: []}
C.update({itemset_size: [[f] for f in order]})

# %%
C
# Out:
# {1: [['3 TRADITIONAL COOKIE CUTTERS  SET'],
#   ['3 TRADITIONAl BISCUIT CUTTERS  SET'],
#   ['ALARM CLOCK BAKELIKE CHOCOLATE'],
#   ['ALARM CLOCK BAKELIKE GREEN'],
#   ['ALARM CLOCK BAKELIKE IVORY'],
#   ['ALARM CLOCK BAKELIKE ORANGE'],
#   ['ALARM CLOCK BAKELIKE PINK'],
#   ['ALARM CLOCK BAKELIKE RED'],
#   ['ANT WHITE WIRE HEART SPIRAL'],
#   ['ASSORTED BOTTLE TOP  MAGNETS'],
#   ['ASSORTED COLOUR BIRD ORNAMENT'],
#   ['ASSORTED COLOUR MINI CASES'],
#   ['BAG 125g SWIRLY MARBLES'],
#   ['BATH BUILDING BLOCK WORD'],
#   ['BIRTHDAY PARTY CORDON BARRIER TAPE'],
#   ['BLUE BIRDHOUSE DECORATION'],
#   ['BLUE DRAWER KNOB ACRYLIC EDWARDIAN'],
#   ['BREAD BIN DINER STYLE PINK'],
#   ['BREAD BIN DINER STYLE RED'],
#   ['CAKE PLATE LOVEBIRD WHITE'],
#   ['CANDLEHOLDER PINK HANGING HEART'],
#   ['CERAMIC CAKE STAND + HANGING CAKES'],
#   ['CHEST OF DRAWERS GINGHAM HEART'],
#   ['CHILDRENS DOLLY GIRL MUG'],
#   ['CHILDRENS SPACEBOY MUG'],
#   ['CHILDS GARDEN BRUSH PINK'],
#   ['CHILLI LIGHTS'],
#   ['CHINESE DRAGON PAPER LANTERNS'],
#   ['CHOCOLATE HOT WATER BOTTLE'],
#   ['CHRISTMAS GINGHAM HEART'],
#   ['CHRISTMAS TREE DECORATION WITH BELL'],
#   ['CHRISTMAS TREE STAR DECORATION'],
#   ['CINAMMON SET OF 9 T-LIGHTS'],
#   ['CLEAR DRAWER KNOB ACRYLIC EDWARDIAN'],
#   ['CREAM CUPID HEARTS COAT HANGER'],
#   ['CREAM HEART CARD HOLDER'],
#   ['CREAM SWEETHEART EGG HOLDER'],
#   ['CUPCAKE LACE PAPER SET 6'],
#   ['DECORATIVE PLANT POT WITH FRIEZE'],
#   ["DOCTOR'S BAG SOFT TOY"],
#   ['DOORMAT AIRMAIL'],
#   ['DOORMAT SPOTTY HOME SWEET HOME'],
#   ['FAIRY TALE COTTAGE NIGHTLIGHT'],
#   ['FAMILY PHOTO FRAME CORNICE'],
#   ['FAUX FUR CHOCOLATE THROW'],
#   ['FEATHER PENCOAL BLACK'],
#   ['FEATHER PENHOT PINK'],
#   ['FEATHER PENLIGHT PINK'],
#   ['FINE WICKER HEART'],
#   ['FLUTED ANTIQUE CANDLE HOLDER'],
#   ['FRENCH BLUE METAL DOOR SIGN 5'],
#   ['GINGERBREAD MAN COOKIE CUTTER'],
#   ['GLASS STAR FROSTED T-LIGHT HOLDER'],
#   ['GRAND CHOCOLATECANDLE'],
#   ['GREEN CHRISTMAS TREE CARD HOLDER'],
#   ['GREEN DRAWER KNOB ACRYLIC EDWARDIAN'],
#   ['GREY HEART HOT WATER BOTTLE'],
#   ['GROW YOUR OWN FLOWERS SET OF 3'],
#   ['HAND WARMER BABUSHKA DESIGN'],
#   ['HAND WARMER BIRD DESIGN'],
#   ['HAND WARMER OWL DESIGN'],
#   ['HAND WARMER RED POLKA DOT'],
#   ['HAND WARMER SCOTTY DOG DESIGN'],
#   ['HAND WARMER UNION JACK'],
#   ['HANGING HEART ZINC T-LIGHT HOLDER'],
#   ['HANGING METAL STAR LANTERN'],
#   ['HOMEMADE JAM SCENTED CANDLES'],
#   ['HOT WATER BOTTLE BABUSHKA'],
#   ['HOT WATER BOTTLE TEA AND SYMPATHY'],
#   ['IVORY HANGING DECORATION  HEART'],
#   ['JAM MAKING SET PRINTED'],
#   ['JAM MAKING SET WITH JARS'],
#   ['JUMBO  BAG BAROQUE BLACK WHITE'],
#   ['JUMBO BAG DOLLY GIRL DESIGN'],
#   ['JUMBO BAG RED RETROSPOT'],
#   ['KNITTED UNION FLAG HOT WATER BOTTLE'],
#   ['LADYBIRD + BEE RAFFIA FOOD COVER'],
#   ['LANTERN CREAM GAZEBO'],
#   ['LIGHT GARLAND BUTTERFILES PINK'],
#   ['LUNCH BAG  BLACK SKULL.'],
#   ['LUNCH BAG DOLLY GIRL DESIGN'],
#   ['LUNCH BOX I LOVE LONDON'],
#   ['MINI CAKE STAND WITH HANGING CAKES'],
#   ['MINT KITCHEN SCALES'],
#   ['MULTI COLOUR SILVER T-LIGHT HOLDER'],
#   ['NATURAL SLATE HEART CHALKBOARD'],
#   ['NUMBER TILE COTTAGE GARDEN 8'],
#   ['ORGANISER WOOD ANTIQUE WHITE'],
#   ['PACK 3 BOXES CHRISTMAS PANNETONE'],
#   ['PACK OF 12 COLOURED PENCILS'],
#   ['PACK OF 12 LONDON TISSUES'],
#   ["PAPER CHAIN KIT 50'S CHRISTMAS"],
#   ['PAPER CHAIN KIT VINTAGE CHRISTMAS'],
#   ['PINK DRAWER KNOB ACRYLIC EDWARDIAN'],
#   ['PLASTERS IN TIN STRONGMAN'],
#   ['POLKADOT PEN'],
#   ['POSTAGE'],
#   ['RED  HARMONICA IN BOX'],
#   ['RED DRAWER KNOB ACRYLIC EDWARDIAN'],
#   ['RED HANGING HEART T-LIGHT HOLDER'],
#   ['RED HEART SHAPE LOVE BUCKET'],
#   ['RED RETROSPOT CAKE STAND'],
#   ['RED STRIPE CERAMIC DRAWER KNOB'],
#   ['RED TOADSTOOL LED NIGHT LIGHT'],
#   ['RED WOOLLY HOTTIE WHITE HEART.'],
#   ['REGENCY CAKESTAND 3 TIER'],
#   ['RETROSPOT CHILDRENS APRON'],
#   ['RETROSPOT RED WASHING UP GLOVES'],
#   ['ROSE COTTAGE KEEPSAKE BOX'],
#   ['ROTATING LEAVES T-LIGHT HOLDER'],
#   ['SCENTED CANDLE IN DIGITALIS TIN'],
#   ['SET 3 WICKER OVAL BASKETS W LIDS'],
#   ['SET 7 BABUSHKA NESTING BOXES'],
#   ['SET OF 20 VINTAGE CHRISTMAS NAPKINS'],
#   ['SET OF 3 NOTEBOOKS IN PARCEL'],
#   ['SET/12 TAPER CANDLES'],
#   ['SET/3 CHRISTMAS DECOUPAGE CANDLES'],
#   ['SINGLE HEART ZINC T-LIGHT HOLDER'],
#   ['SOAP DISH BROCANTE'],
#   ['SOLDIERS EGG CUP'],
#   ['SPACEBOY CHILDRENS EGG CUP'],
#   ['STAR PORTABLE TABLE LIGHT'],
#   ['STRAWBERRY CERAMIC TRINKET BOX'],
#   ['STRING OF STARS CARD HOLDER'],
#   ['STRIPEY CHOCOLATE NESTING BOXES'],
#   ['SWISS CHALET TREE DECORATION'],
#   ['TRADITIONAL CHRISTMAS RIBBONS'],
#   ['TRIPLE PHOTO FRAME CORNICE'],
#   ['VICTORIAN SEWING BOX LARGE'],
#   ['VINTAGE HEADS AND TAILS CARD GAME'],
#   ['VINTAGE POST OFFICE CABINET'],
#   ['VINTAGE SNAP CARDS'],
#   ['WASHROOM METAL SIGN'],
#   ['WHITE HANGING HEART T-LIGHT HOLDER'],
#   ['WHITE JEWELLED HEART DECORATION'],
#   ['WHITE METAL LANTERN'],
#   ['WHITE WIRE EGG HOLDER'],
#   ['WHITE WOOD GARDEN PLANT LADDER'],
#   ['WOODEN ADVENT CALENDAR RED'],
#   ['WOODEN FRAME ANTIQUE WHITE'],
#   ['WOODEN OWLS LIGHT GARLAND'],
#   ['ZINC WILLIE WINKIE  CANDLE STICK']]}

# %% [markdown]
# __Create L1__

# %%
supp_count_L = {}
f, sup, new_discarded = get_frequent(C[itemset_size], filtered_transactions, min_support, discarded)
discarded.update({itemset_size : new_discarded})
L.update({itemset_size : f})
supp_count_L.update({itemset_size : sup})

# %%
print_table(L[1], supp_count_L[1])
# Out:
# Itemset | Frequency
# ['ASSORTED COLOUR BIRD ORNAMENT']  :  13
# ['CHOCOLATE HOT WATER BOTTLE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER']  :  15
# ['HAND WARMER BIRD DESIGN']  :  20
# ['HAND WARMER OWL DESIGN']  :  17
# ['HAND WARMER RED POLKA DOT']  :  15
# ['HAND WARMER SCOTTY DOG DESIGN']  :  20
# ['HAND WARMER UNION JACK']  :  29
# ['HOMEMADE JAM SCENTED CANDLES']  :  13
# ['HOT WATER BOTTLE BABUSHKA']  :  13
# ['HOT WATER BOTTLE TEA AND SYMPATHY']  :  14
# ['JAM MAKING SET PRINTED']  :  24
# ['JAM MAKING SET WITH JARS']  :  13
# ['JUMBO BAG RED RETROSPOT']  :  15
# ['KNITTED UNION FLAG HOT WATER BOTTLE']  :  21
# ["PAPER CHAIN KIT 50'S CHRISTMAS"]  :  17
# ['PAPER CHAIN KIT VINTAGE CHRISTMAS']  :  16
# ['RED WOOLLY HOTTIE WHITE HEART.']  :  26
# ['REGENCY CAKESTAND 3 TIER']  :  17
# ['SET 7 BABUSHKA NESTING BOXES']  :  21
# ['VINTAGE HEADS AND TAILS CARD GAME']  :  11
# ['WHITE HANGING HEART T-LIGHT HOLDER']  :  29
# ['WHITE METAL LANTERN']  :  16
# ['WOODEN FRAME ANTIQUE WHITE']  :  17

# %% [markdown]
# ## Apriori algorithm

# %%
k = itemset_size + 1
convergence = False
while not convergence:
    C.update({ k : join_set_itemsets(L[k-1], order)})
    f, sup, new_discarded = get_frequent(C[k], filtered_transactions, min_support, discarded) 
    discarded.update({k : new_discarded})
    L.update({k : f})
    supp_count_L.update({k : sup})
    if len(L[k]) == 0:
        convergence = True
    else:
        print("Table L{}: \n".format(k))
        print_table(L[k], supp_count_L[k])
    k += 1
# Out:
# Table L2:
#
# Itemset | Frequency
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN']  :  14
# ['HAND WARMER RED POLKA DOT', 'HAND WARMER UNION JACK']  :  15
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.']  :  19
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES']  :  15
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  19
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN']  :  16
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'WOODEN FRAME ANTIQUE WHITE']  :  14
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  15
# ['RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  19
# ['RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  16
# ['RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  14
# ['SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  16
# ['WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  14
# ['WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
#
#
# Table L3:
#
# Itemset | Frequency
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  15
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  18
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  16
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  14
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  16
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  14
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  16
# ['RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  14
# ['RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
#
#
# Table L4:
#
# Itemset | Frequency
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  15
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  16
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  14
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
#
#
# Table L5:
#
# Itemset | Frequency
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  15
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
#
#
# Table L6:
#
# Itemset | Frequency
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  13
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  14
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  13
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
#
#
# Table L7:
#
# Itemset | Frequency
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11
# ['GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  12
#
#
# Table L8:
#
# Itemset | Frequency
# ['CREAM CUPID HEARTS COAT HANGER', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'WOODEN FRAME ANTIQUE WHITE']  :  11

# %% [markdown]
# ## Generating the Association rules

# %%
assoc_rules_str = ""
num_trans = len(filtered_transactions)
for i in range(1, len(L)):
    for j in range(len(L[i])):
        s = powerset(L[i][j])
        for z in s:
            S = set(z)
            X = set(L[i][j])
            X_S = set(X-S)
            sup_x = supp_count_L[i][j]
            sup_x_s = count_occurences(X_S, filtered_transactions)
            conf = sup_x / count_occurences(S, filtered_transactions)
            lift = conf / (sup_x_s / num_trans)
            if conf >= min_confidence:
                assoc_rules_str += write_rules(X, X_S, S, conf, sup_x, lift, num_trans)

# %%
print(assoc_rules_str)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
with open('apriori_result.txt', 'w') as f:
    f.write(assoc_rules_str)
